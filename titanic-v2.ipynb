# %%
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Imputer
from sklearn.metrics import mean_absolute_error
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
import random as rnd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor, XGBClassifier

# %%
import os
print(os.listdir('.'))
print(os.getcwd())
print(os.listdir('..'))
print(os.listdir('../lib/kaggle/competitions/twosigmanews/'))
# Out:
# ['__output__.json', '__notebook__.ipynb']
# /kaggle/working
# ['lib', 'input', 'working', 'src']
# ['__init__.py', 'env.py']

# %%
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
train_set_path = '../input/train.csv'
test_set_path = '../input/test.csv'
gender_submission = '../input/gender_submission.csv'

import os
#print(os.listdir("../input"))

train_data = pd.read_csv(train_set_path) # Carrega o arquivo
train_data_age = pd.read_csv(train_set_path) # Carrega o arquivo

test_data = pd.read_csv(test_set_path)
test_data_age = pd.read_csv(test_set_path)
gender_submission =  pd.read_csv(gender_submission)
#train_data.describe()

# %%
train_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train_data[['PassengerId', 'Pclass', 'Sex','Age','SibSp','Parch','Fare','Embarked']]
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0              1       3    male  22.0      1      0    7.2500        S
# 1              2       1  female  38.0      1      0   71.2833        C
# 2              3       3  female  26.0      0      0    7.9250        S
# 3              4       1  female  35.0      1      0   53.1000        S
# 4              5       3    male  35.0      0      0    8.0500        S
# 5              6       3    male   NaN      0      0    8.4583        Q
# 6              7       1    male  54.0      0      0   51.8625        S
# 7              8       3    male   2.0      3      1   21.0750        S
# 8              9       3  female  27.0      0      2   11.1333        S
# 9             10       2  female  14.0      1      0   30.0708        C
# 10            11       3  female   4.0      1      1   16.7000        S
# 11            12       1  female  58.0      0      0   26.5500        S
# ...

# %%
pd.get_dummies(train_data[['PassengerId','Pclass','Name', 'Sex','Age','SibSp','Parch','Fare','Cabin','Embarked']])
# Out:
#      PassengerId  Pclass   Age     ...      Embarked_C  Embarked_Q  Embarked_S
# 0              1       3  22.0     ...               0           0           1
# 1              2       1  38.0     ...               1           0           0
# 2              3       3  26.0     ...               0           0           1
# 3              4       1  35.0     ...               0           0           1
# 4              5       3  35.0     ...               0           0           1
# 5              6       3   NaN     ...               0           1           0
# 6              7       1  54.0     ...               0           0           1
# 7              8       3   2.0     ...               0           0           1
# 8              9       3  27.0     ...               0           0           1
# 9             10       2  14.0     ...               1           0           0
# 10            11       3   4.0     ...               0           0           1
# ...

# %%
title = pd.DataFrame()
titleTest = pd.DataFrame()
# we extract the title from each name
title[ 'Title' ] = train_data[ 'Name' ].map( lambda name: name.split( ',' )[1].split( '.' )[0].strip() )
titleTest[ 'Title' ] = test_data[ 'Name' ].map( lambda name: name.split( ',' )[1].split( '.' )[0].strip() )

# a map of more aggregated titles
Title_Dictionary = {
                    "Capt":       "Officer",
                    "Col":        "Officer",
                    "Major":      "Officer",
                    "Jonkheer":   "Royalty",
                    "Don":        "Royalty",
                    "Sir" :       "Royalty",
                    "Dr":         "Officer",
                    "Rev":        "Officer",
                    "the Countess":"Royalty",
                    "Dona":       "Royalty",
                    "Mme":        "Mrs",
                    "Mlle":       "Miss",
                    "Ms":         "Mrs",
                    "Mr" :        "Mr",
                    "Mrs" :       "Mrs",
                    "Miss" :      "Miss",
                    "Master" :    "Master",
                    "Lady" :      "Royalty"

                    }

# we map each title
title[ 'Title' ] = title.Title.map( Title_Dictionary )
titleTest[ 'Title' ] = titleTest.Title.map( Title_Dictionary )
#title = pd.concat( [ title , titles_dummies ] , axis = 1 )
train_data['Title'] = title
test_data['Title'] = titleTest


title.head()
# Out:
#   Title
# 0    Mr
# 1   Mrs
# 2  Miss
# 3   Mrs
# 4    Mr

# %%
train_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Title           object
# dtype: object

# %%
dataset = pd.DataFrame()
datasetTest = pd.DataFrame()

print ('DataSET')
#Discrete variables
dataset['FamilySize'] = train_data ['SibSp'] + train_data['Parch'] + 1

dataset['IsAlone'] = 1 #initialize to yes/1 is alone
dataset['IsAlone'].loc[dataset['FamilySize'] > 1] = 0 # now update to no/0 if family size is greater than 1
#dataset['FareBin'] = pd.qcut(train_data['Fare'], 9)
#train_data['Age'].fillna(train_data['Age'].median(), inplace = True)
#train_data['Age']
percentil = pd.qcut(train_data['Fare'], 9,retbins=True)
print (percentil[1])
test_data['Fare'].fillna(test_data['Fare'].median(), inplace = True)
for df in [train_data,test_data]:
    df['FareBin'] = pd.cut(df['Fare'],percentil[1], include_lowest=True)
# Daqui para baixo, fazendo para o Teste
#Discrete variables
datasetTest['FamilySize'] = test_data ['SibSp'] + test_data['Parch'] + 1

datasetTest['IsAlone'] = 1 #initialize to yes/1 is alone
datasetTest['IsAlone'].loc[datasetTest['FamilySize'] > 1] = 0 # now update to no/0 if family size is greater than 1
#datasetTest['FareBin'] = pd.qcut(test_data['Fare'], 9)
#test_data['Age'].fillna(test_data['Age'].median(), inplace = True)
#test_data['Age'].fillna(test_data['Age'].median(), inplace = True)
train_data['Ticket2']=train_data.Ticket.apply(lambda x : len(x))
test_data['Ticket2']=test_data.Ticket.apply(lambda x : len(x))
train_data.Cabin=train_data.Cabin.fillna("unknow")
test_data.Cabin=test_data.Cabin.fillna("unknow")

train_data['Cabin2']=train_data.Cabin.apply(lambda x : len(x))
test_data['Cabin2']=test_data.Cabin.apply(lambda x : len(x))
train_data.dtypes
# Out:
# DataSET
# [  0.           7.73284444   7.8958       8.6625      13.
#   16.7         26.          35.11111111  73.5        512.3292    ]
# PassengerId       int64
# Survived          int64
# Pclass            int64
# Name             object
# Sex              object
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Cabin            object
# Embarked         object
# Title            object
# FareBin        category
# Ticket2           int64
# Cabin2            int64
# dtype: object

# %%
train_data['IsAlone'] = dataset['IsAlone']
test_data['IsAlone'] = datasetTest['IsAlone']

my_pipeline = make_pipeline(Imputer(),  RandomForestRegressor() ) # Divindo o conjuntos
#de teste em um de teste e um de treinamento para testar o impacto da quantidade de árvores e da profundidade máxima de arvores
# e cheguei a conclusão que não é muito impactante, pois sempre fica em torno de 1.7 ~ 2 o mean absolut error
featuresAge = ['Sex','Title','SibSp','Parch','IsAlone']
#train_data['Age'].fillna(train_data['Age'].median(), inplace = True)
train_data_age_X = train_data[featuresAge]
nullage = pd.DataFrame
nullage = train_data_age.Age
y_age = nullage.dropna()
y_age2 = pd.get_dummies(y_age)
one_hot_X_age = pd.get_dummies(train_data_age)
my_pipeline.fit(one_hot_X_age.dropna(subset=['Age']), y_age)
predictTest = my_pipeline.predict(one_hot_X_age)
predictTest
train_data.Age = predictTest

test_data_age_X = test_data[featuresAge]
nullagetest = pd.DataFrame
nullagetest = test_data_age.Age
y_agetest = nullagetest.dropna()
y_age2test = pd.get_dummies(y_agetest)
one_hot_X_age_test = pd.get_dummies(test_data_age)
my_pipeline.fit(one_hot_X_age_test.dropna(subset=['Age']), y_agetest)
predictTesttest = my_pipeline.predict(one_hot_X_age_test)
test_data.Age = predictTesttest
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
datasetTest['AgeBin'] = pd.cut(test_data['Age'].astype(int), 5)
dataset['AgeBin'] = pd.cut(train_data['Age'].astype(int), 5)

# %%
y = train_data.Survived
train_data['FamilySize'] = dataset['FamilySize']
train_data['AgeBin'] = dataset['AgeBin']
#train_data['FareBin'] = dataset['FareBin']
features = ['Pclass', 'Sex','Embarked','Title','FamilySize','IsAlone','AgeBin','FareBin','Ticket2','Cabin2']
X = train_data[features]
one_hot_X = pd.get_dummies(X)
train_X, val_X, train_y, val_y = train_test_split(one_hot_X, y, random_state = 0)
test_data['FamilySize'] = datasetTest['FamilySize']
test_data['AgeBin'] = datasetTest['AgeBin']
#test_data['FareBin'] = datasetTest['FareBin']
testX = test_data[features]
one_hot_testX = pd.get_dummies(testX)

#print(one_hot_X.columns)
#print(one_hot_testX.columns)
final_train, final_test = one_hot_X.align(one_hot_testX,join='left', axis=1)
#train_X, val_X, train_y, val_y = train_test_split(one_hot_X, one_hot_y, random_state = 0)
#print(train_X.columns)
#print(val_X.columns)
#one_hot_encoded_train_y = pd.get_dummies(train_y)
#one_hot_encoded_train_X = pd.get_dummies(train_X)
#one_hot_encoded_val_X = pd.get_dummies(val_X)
#v = one_hot_encoded_train_X.columns
one_hot_X.head()
#print(one_hot_encoded_val_X.columns)
# Out:
#    Pclass           ...             FareBin_(73.5, 512.329]
# 0       3           ...                                   0
# 1       1           ...                                   0
# 2       3           ...                                   0
# 3       1           ...                                   0
# 4       3           ...                                   0
#
# [5 rows x 30 columns]

# %% [markdown]
# UTILIZANDO ÁRVORE PARA ADVINHAR AS IDADES NULAS

# %% [markdown]
# *

# %%
 '''my_pipeline = make_pipeline(Imputer(), XGBClassifier())

my_pipeline.fit(final_train, y)

predictionsTrain = my_pipeline.predict(final_train)
#print(mean_absolute_error(one_hot_y,predictions))
predictTest = my_pipeline.predict(final_test)
#print(testX.PassengerId)'''
# Out:
# 'my_pipeline = make_pipeline(Imputer(), XGBClassifier())\n\nmy_pipeline.fit(final_train, y)\n\npredictionsTrain = my_pipeline.predict(final_train)\n#print(mean_absolute_error(one_hot_y,predictions))\npredictTest = my_pipeline.predict(final_test)\n#print(testX.PassengerId)'

# %%
my_pipeline = make_pipeline(Imputer(),  GaussianNB() )
#de teste em um de teste e um de treinamento para testar o impacto da quantidade de árvores e da profundidade máxima de arvores
# e cheguei a conclusão que não é muito impactante, pois sempre fica em torno de 1.7 ~ 2 o mean absolut error
my_pipeline.fit(final_train, y)
predictTest2 = my_pipeline.score(final_train,y)
print(predictTest2)
predictTest = my_pipeline.predict(final_test)
my_pipeline.fit(train_X, train_y)
# get predicted prices on validation data
val_predictions = my_pipeline.predict(val_X)
print("mean abs error = " ,mean_absolute_error(val_y, val_predictions))
# Out:
# 0.7811447811447811
# mean abs error =  0.242152466367713
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
my_pipeline = make_pipeline(Imputer(),  SVC() )
#de teste em um de teste e um de treinamento para testar o impacto da quantidade de árvores e da profundidade máxima de arvores
# e cheguei a conclusão que não é muito impactante, pois sempre fica em torno de 1.7 ~ 2 o mean absolut error
my_pipeline.fit(final_train, y)
predictTest2 = my_pipeline.score(final_train,y)
print(predictTest2)
predictTest = my_pipeline.predict(final_test)
my_pipeline.fit(train_X, train_y)
# get predicted prices on validation data
val_predictions = my_pipeline.predict(val_X)
print("mean abs error = " ,mean_absolute_error(val_y, val_predictions))
# Out:
# 0.8361391694725028
# mean abs error =  0.18385650224215247
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
my_pipeline = make_pipeline(Imputer(),  XGBClassifier(n_estimators=2000,learning_rate=0.05) )
#de teste em um de teste e um de treinamento para testar o impacto da quantidade de árvores e da profundidade máxima de arvores
# e cheguei a conclusão que não é muito impactante, pois sempre fica em torno de 1.7 ~ 2 o mean absolut error
final_train.head()
my_pipeline.fit(final_train, y)
predictTest2 = my_pipeline.score(final_train,y)
print(predictTest2)
predictTest = my_pipeline.predict(one_hot_testX)
my_pipeline.fit(train_X, train_y)
# get predicted prices on validation data
val_predictions = my_pipeline.predict(val_X)
print("mean abs error = " ,mean_absolute_error(val_y, val_predictions))
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# 0.9113355780022446
# mean abs error =  0.16143497757847533

# %%
one_hot_X.isnull().sum()
y.isnull().sum()
final_test.isnull().sum()
# Out:
# Pclass                       0
# FamilySize                   0
# IsAlone                      0
# Ticket2                      0
# Cabin2                       0
# Sex_female                   0
# Sex_male                     0
# Embarked_C                   0
# Embarked_Q                   0
# Embarked_S                   0
# Title_Master                 0
# Title_Miss                   0
# Title_Mr                     0
# Title_Mrs                    0
# Title_Officer                0
# Title_Royalty                0
# AgeBin_(-0.074, 14.8]      418
# AgeBin_(14.8, 29.6]        418
# AgeBin_(29.6, 44.4]        418
# AgeBin_(44.4, 59.2]        418
# AgeBin_(59.2, 74.0]        418
# FareBin_(-0.001, 7.733]      0
# FareBin_(7.733, 7.896]       0
# FareBin_(7.896, 8.662]       0
# FareBin_(8.662, 13.0]        0
# FareBin_(13.0, 16.7]         0
# FareBin_(16.7, 26.0]         0
# FareBin_(26.0, 35.111]       0
# FareBin_(35.111, 73.5]       0
# FareBin_(73.5, 512.329]      0
# ...

# %%
svc=make_pipeline(StandardScaler(),SVC(random_state=1))
r=[0.0001,0.001,0.1,1,10,50,100]
PSVM=[{'svc__C':r, 'svc__kernel':['linear']},
      {'svc__C':r, 'svc__gamma':r, 'svc__kernel':['rbf']}]
GSSVM=GridSearchCV(estimator=svc, param_grid=PSVM, scoring='accuracy', cv=2)
scores_svm=cross_val_score(GSSVM, one_hot_X.astype(float), y,scoring='accuracy', cv=5)
np.mean(scores_svm)

model=GSSVM.fit(one_hot_X.astype(float), y)
pred=model.predict(one_hot_testX)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/pipeline.py:331: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)

# %%
result = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': pred})
result.to_csv("submit9CSV.csv",index=False)

# %%
print ('Terminado')
# Out:
# Terminado
